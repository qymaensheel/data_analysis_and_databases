# %% [markdown]
# ### Bartosz Nieroda
#
# # Analiza i Bazy Danych
# ## Lab 1

# %% [markdown]
# Zadanie 3:
# Definicja funkcji oraz wyrysowanie wykresów

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

def f(x):
    return x**2 + 5

# %%
# 1. 
x = np.linspace(-1, 1)
y = f(x)
plt.figure()
plt.grid()
plt.title('x^2 + 5')
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x,y)

# %%
# 2. 
x = np.linspace(-6, 6)
y = f(x)
plt.figure()
plt.grid()
plt.title('x^2 + 5')
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x,y)

# %% [markdown]
# Zadanie 4:
# Utworzenie DataFrame, wpisanie rekordów i wyświetlenie ich

# %%
# 3. 
x = np.linspace(0, 5)
y = f(x)
plt.figure()
plt.grid()
plt.title('x^2 + 5')
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x,y)

# %% [markdown]
# ## Pandas dataframes

# %%
df = pd.DataFrame(columns=['name', 'surname', 'age', 'sex'])
df['name'] = ['bartosz', 
             'andrzej',
             'maja',
             'ania',
             'mike']

df ['surname'] = ['nieroda',
                 'grabowski',
                 'pszczolka',
                 'testowa',
                 'wazowski']

df['age']=[23, 15, 31, 4, 20]

df['sex']=['M', 'M', 'F', 'F', 'M']

print(df)
print('\n\n')
print(df.info())
print('\n\n')
print(df.describe())
print('\n\n')
print(df.head(5))
# Out:
#       name    surname  age sex
# 0  bartosz    nieroda   23   M
# 1  andrzej  grabowski   15   M
# 2     maja  pszczolka   31   F
# 3     ania    testowa    4   F
# 4     mike   wazowski   20   M
#
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   surname  5 non-null      object
#  2   age      5 non-null      int64
#  3   sex      5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 288.0+ bytes
# None
#
#
#
#              age
# count   5.000000
# mean   18.600000
# std    10.014989
# min     4.000000
# 25%    15.000000
# 50%    20.000000
# 75%    23.000000
# max    31.000000
#
#
#
#       name    surname  age sex
# 0  bartosz    nieroda   23   M
# 1  andrzej  grabowski   15   M
# 2     maja  pszczolka   31   F
# 3     ania    testowa    4   F
# 4     mike   wazowski   20   M
